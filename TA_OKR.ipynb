# %% [markdown]
# ## Importing Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from random import randrange
import scipy as sp
from scipy import stats
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_graphviz
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn import tree
import graphviz
import pickle
import warnings

# %% [markdown]
# ## Load Data

# %%
# Membaca data pada excel
data = pd.read_csv('data_sintetis2.csv')
data
# Out:
#             NIP             Nama        Jabatan  \
# 0   466-60-3518   Bradley Galvan  Staff Operasi
# 1   167-52-0691    Sharon Harris  Staff Operasi
# 2   377-11-9746       David Cook  Staff Operasi
# 3   818-12-3550      Aaron Smith  Staff Operasi
# 4   342-94-2910  Leslie Mckinney  Staff Operasi
# ..          ...              ...            ...
# 95  232-54-4400  Heather Roberts  Staff Operasi
# 96  692-51-4169       Jon Dawson  Staff Operasi
# 97  206-64-5705     Teresa Lynch  Staff Operasi
# 98  574-87-7256     Adriana Hart  Staff Operasi
# 99  299-02-8126   Daniel Johnson  Staff Operasi
#
#                                           Objective 1  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2   Meningkatkan efektifitas sumber daya penunjang...
# 3   Meningkatkan efektifitas sumber daya penunjang...
# 4   Meningkatkan efektifitas sumber daya penunjang...
# ..                                                ...
# 95  Menurunkan tingkat iregularitas sesuai target ...
# 96  Menurunkan tingkat iregularitas sesuai target ...
# 97  Menurunkan tingkat iregularitas sesuai target ...
# 98  Menurunkan tingkat iregularitas sesuai target ...
# 99  Meningkatkan efektifitas sumber daya penunjang...
#
#                                          Key Result 1  \
# 0   Tersedianya laporan pola operasi tersier setia...
# 1   Tercapainya kinerja SWP Pos Same Day Wilker (K...
# 2   Tercapainya optimalisasi kbm tersier setiap bulan
# 3   Tersedianya laporan evaluasi implementasi oran...
# 4   Tercapainya optimalisasi kbm tersier setiap bulan
# ..                                                ...
# 95  Tercapainya penurunan jumlah kiriman gagal xra...
# 96  Tercapainya keberangkatan moda angkutan sesuai...
# 97  Tersedianya laporan evaluasi kiriman iregulari...
# 98  Tersedianya laporan evaluasi kiriman iregulari...
# 99  Tersedianya monitoring kebutuhan dan penataan ...
#
#                                           Objective 2  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2             Mendorong efisiensi cost bidang operasi
# 3             Mendorong efisiensi cost bidang operasi
# 4             Mendorong efisiensi cost bidang operasi
# ..                                                ...
# 95            Mendorong efisiensi cost bidang operasi
# 96  Meningkatkan efektifitas sumber daya penunjang...
# 97            Mendorong efisiensi cost bidang operasi
# 98            Mendorong efisiensi cost bidang operasi
# 99            Mendorong efisiensi cost bidang operasi
#
#                                          Key Result 2  Target Q1  Target Q2  \
# 0   Tercapainya optimalisasi pola operasi tersier ...         60         88
# 1   Tercapainya kinerja SWP Pos Reguler Wilker (KC...         78         64
# 2   Tersedianya monitoring kebutuhan dan penataan ...          1          2
# 3   Tercapainya optimalisasi kbm tersier setiap bulan          5          6
# 4   Tersedianya laporan evaluasi implementasi oran...         15         15
# ..                                                ...        ...        ...
# 95  Tercapainya keberangkatan moda angkutan sesuai...         14          5
# 96  Tersedianya laporan evaluasi kiriman iregulari...         10          9
# 97  Tersedianya laporan keberangkatan moda angkuta...         15         15
# 98  Tercapainya penurunan jumlah kiriman gagal xra...         11          7
# 99  Tersedianya laporan evaluasi implementasi oran...         15         14
#
#         Unit  Complexity  Progress Q1  Progress Q2  Assignor Rating Q1  \
# 0    percent           1           59           82                   3
# 1    percent           1           71           62                   5
# 2    laporan           4            1            1                   2
# 3   kegiatan           1            4            6                   5
# 4   kegiatan           5            7           14                   3
# ..       ...         ...          ...          ...                 ...
# 95  kegiatan           3           13            1                   1
# 96   laporan           1           10            6                   2
# 97  kegiatan           2            2           14                   4
# 98  kegiatan           2           11            6                   5
# 99   laporan           2            4            5                   4
#
#     Assignor Rating Q2  Nilai Quartal 1  Nilai Quartal 2    Predikat  \
# 0                    2        95.000000        87.909091   91.454545
# 1                    5        98.615385       102.125000  100.370192
# 2                    4        92.000000        70.000000   81.000000
# 3                    1        92.000000        88.000000   90.000000
# 4                    1        64.000000        84.000000   74.000000
# ..                 ...              ...              ...         ...
# 95                   1        83.714286        40.000000   61.857143
# 96                   1        92.000000        68.000000   80.000000
# 97                   1        48.000000        84.000000   66.000000
# 98                   4       104.000000        91.428571   97.714286
# 99                   2        56.000000        53.428571   54.714286
#
#        Tanggal Kategori Predikat
# 0   2024-08-08         Memuaskan
# 1   2024-08-08  Sangat Memuaskan
# 2   2024-08-08              Baik
# 3   2024-08-08         Memuaskan
# 4   2024-08-08              Baik
# ..         ...               ...
# 95  2024-08-08             Cukup
# 96  2024-08-08              Baik
# 97  2024-08-08             Cukup
# 98  2024-08-08         Memuaskan
# 99  2024-08-08             Cukup
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# Mengganti spasi dengan underscore pada nama kolom
data.columns = data.columns.str.replace(' ', '_')

# Menampilkan DataFrame dengan kolom yang sudah diubah
print(data)
# Out:
#             NIP             Nama        Jabatan  \
# 0   466-60-3518   Bradley Galvan  Staff Operasi
# 1   167-52-0691    Sharon Harris  Staff Operasi
# 2   377-11-9746       David Cook  Staff Operasi
# 3   818-12-3550      Aaron Smith  Staff Operasi
# 4   342-94-2910  Leslie Mckinney  Staff Operasi
# ..          ...              ...            ...
# 95  232-54-4400  Heather Roberts  Staff Operasi
# 96  692-51-4169       Jon Dawson  Staff Operasi
# 97  206-64-5705     Teresa Lynch  Staff Operasi
# 98  574-87-7256     Adriana Hart  Staff Operasi
# 99  299-02-8126   Daniel Johnson  Staff Operasi
#
#                                           Objective_1  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2   Meningkatkan efektifitas sumber daya penunjang...
# 3   Meningkatkan efektifitas sumber daya penunjang...
# 4   Meningkatkan efektifitas sumber daya penunjang...
# ..                                                ...
# 95  Menurunkan tingkat iregularitas sesuai target ...
# 96  Menurunkan tingkat iregularitas sesuai target ...
# 97  Menurunkan tingkat iregularitas sesuai target ...
# 98  Menurunkan tingkat iregularitas sesuai target ...
# 99  Meningkatkan efektifitas sumber daya penunjang...
#
#                                          Key_Result_1  \
# 0   Tersedianya laporan pola operasi tersier setia...
# 1   Tercapainya kinerja SWP Pos Same Day Wilker (K...
# 2   Tercapainya optimalisasi kbm tersier setiap bulan
# 3   Tersedianya laporan evaluasi implementasi oran...
# 4   Tercapainya optimalisasi kbm tersier setiap bulan
# ..                                                ...
# 95  Tercapainya penurunan jumlah kiriman gagal xra...
# 96  Tercapainya keberangkatan moda angkutan sesuai...
# 97  Tersedianya laporan evaluasi kiriman iregulari...
# 98  Tersedianya laporan evaluasi kiriman iregulari...
# 99  Tersedianya monitoring kebutuhan dan penataan ...
#
#                                           Objective_2  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2             Mendorong efisiensi cost bidang operasi
# 3             Mendorong efisiensi cost bidang operasi
# 4             Mendorong efisiensi cost bidang operasi
# ..                                                ...
# 95            Mendorong efisiensi cost bidang operasi
# 96  Meningkatkan efektifitas sumber daya penunjang...
# 97            Mendorong efisiensi cost bidang operasi
# 98            Mendorong efisiensi cost bidang operasi
# 99            Mendorong efisiensi cost bidang operasi
#
#                                          Key_Result_2  Target_Q1  Target_Q2  \
# 0   Tercapainya optimalisasi pola operasi tersier ...         60         88
# 1   Tercapainya kinerja SWP Pos Reguler Wilker (KC...         78         64
# 2   Tersedianya monitoring kebutuhan dan penataan ...          1          2
# 3   Tercapainya optimalisasi kbm tersier setiap bulan          5          6
# 4   Tersedianya laporan evaluasi implementasi oran...         15         15
# ..                                                ...        ...        ...
# 95  Tercapainya keberangkatan moda angkutan sesuai...         14          5
# 96  Tersedianya laporan evaluasi kiriman iregulari...         10          9
# 97  Tersedianya laporan keberangkatan moda angkuta...         15         15
# 98  Tercapainya penurunan jumlah kiriman gagal xra...         11          7
# 99  Tersedianya laporan evaluasi implementasi oran...         15         14
#
#         Unit  Complexity  Progress_Q1  Progress_Q2  Assignor_Rating_Q1  \
# 0    percent           1           59           82                   3
# 1    percent           1           71           62                   5
# 2    laporan           4            1            1                   2
# 3   kegiatan           1            4            6                   5
# 4   kegiatan           5            7           14                   3
# ..       ...         ...          ...          ...                 ...
# 95  kegiatan           3           13            1                   1
# 96   laporan           1           10            6                   2
# 97  kegiatan           2            2           14                   4
# 98  kegiatan           2           11            6                   5
# 99   laporan           2            4            5                   4
#
#     Assignor_Rating_Q2  Nilai_Quartal_1  Nilai_Quartal_2    Predikat  \
# 0                    2        95.000000        87.909091   91.454545
# 1                    5        98.615385       102.125000  100.370192
# 2                    4        92.000000        70.000000   81.000000
# 3                    1        92.000000        88.000000   90.000000
# 4                    1        64.000000        84.000000   74.000000
# ..                 ...              ...              ...         ...
# 95                   1        83.714286        40.000000   61.857143
# 96                   1        92.000000        68.000000   80.000000
# 97                   1        48.000000        84.000000   66.000000
# 98                   4       104.000000        91.428571   97.714286
# 99                   2        56.000000        53.428571   54.714286
#
#        Tanggal Kategori_Predikat
# 0   2024-08-08         Memuaskan
# 1   2024-08-08  Sangat Memuaskan
# 2   2024-08-08              Baik
# 3   2024-08-08         Memuaskan
# 4   2024-08-08              Baik
# ..         ...               ...
# 95  2024-08-08             Cukup
# 96  2024-08-08              Baik
# 97  2024-08-08             Cukup
# 98  2024-08-08         Memuaskan
# 99  2024-08-08             Cukup
#
# [100 rows x 20 columns]

# %%
data = data.drop_duplicates()
data
# Out:
#             NIP             Nama        Jabatan  \
# 0   466-60-3518   Bradley Galvan  Staff Operasi
# 1   167-52-0691    Sharon Harris  Staff Operasi
# 2   377-11-9746       David Cook  Staff Operasi
# 3   818-12-3550      Aaron Smith  Staff Operasi
# 4   342-94-2910  Leslie Mckinney  Staff Operasi
# ..          ...              ...            ...
# 95  232-54-4400  Heather Roberts  Staff Operasi
# 96  692-51-4169       Jon Dawson  Staff Operasi
# 97  206-64-5705     Teresa Lynch  Staff Operasi
# 98  574-87-7256     Adriana Hart  Staff Operasi
# 99  299-02-8126   Daniel Johnson  Staff Operasi
#
#                                           Objective_1  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2   Meningkatkan efektifitas sumber daya penunjang...
# 3   Meningkatkan efektifitas sumber daya penunjang...
# 4   Meningkatkan efektifitas sumber daya penunjang...
# ..                                                ...
# 95  Menurunkan tingkat iregularitas sesuai target ...
# 96  Menurunkan tingkat iregularitas sesuai target ...
# 97  Menurunkan tingkat iregularitas sesuai target ...
# 98  Menurunkan tingkat iregularitas sesuai target ...
# 99  Meningkatkan efektifitas sumber daya penunjang...
#
#                                          Key_Result_1  \
# 0   Tersedianya laporan pola operasi tersier setia...
# 1   Tercapainya kinerja SWP Pos Same Day Wilker (K...
# 2   Tercapainya optimalisasi kbm tersier setiap bulan
# 3   Tersedianya laporan evaluasi implementasi oran...
# 4   Tercapainya optimalisasi kbm tersier setiap bulan
# ..                                                ...
# 95  Tercapainya penurunan jumlah kiriman gagal xra...
# 96  Tercapainya keberangkatan moda angkutan sesuai...
# 97  Tersedianya laporan evaluasi kiriman iregulari...
# 98  Tersedianya laporan evaluasi kiriman iregulari...
# 99  Tersedianya monitoring kebutuhan dan penataan ...
#
#                                           Objective_2  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2             Mendorong efisiensi cost bidang operasi
# 3             Mendorong efisiensi cost bidang operasi
# 4             Mendorong efisiensi cost bidang operasi
# ..                                                ...
# 95            Mendorong efisiensi cost bidang operasi
# 96  Meningkatkan efektifitas sumber daya penunjang...
# 97            Mendorong efisiensi cost bidang operasi
# 98            Mendorong efisiensi cost bidang operasi
# 99            Mendorong efisiensi cost bidang operasi
#
#                                          Key_Result_2  Target_Q1  Target_Q2  \
# 0   Tercapainya optimalisasi pola operasi tersier ...         60         88
# 1   Tercapainya kinerja SWP Pos Reguler Wilker (KC...         78         64
# 2   Tersedianya monitoring kebutuhan dan penataan ...          1          2
# 3   Tercapainya optimalisasi kbm tersier setiap bulan          5          6
# 4   Tersedianya laporan evaluasi implementasi oran...         15         15
# ..                                                ...        ...        ...
# 95  Tercapainya keberangkatan moda angkutan sesuai...         14          5
# 96  Tersedianya laporan evaluasi kiriman iregulari...         10          9
# 97  Tersedianya laporan keberangkatan moda angkuta...         15         15
# 98  Tercapainya penurunan jumlah kiriman gagal xra...         11          7
# 99  Tersedianya laporan evaluasi implementasi oran...         15         14
#
#         Unit  Complexity  Progress_Q1  Progress_Q2  Assignor_Rating_Q1  \
# 0    percent           1           59           82                   3
# 1    percent           1           71           62                   5
# 2    laporan           4            1            1                   2
# 3   kegiatan           1            4            6                   5
# 4   kegiatan           5            7           14                   3
# ..       ...         ...          ...          ...                 ...
# 95  kegiatan           3           13            1                   1
# 96   laporan           1           10            6                   2
# 97  kegiatan           2            2           14                   4
# 98  kegiatan           2           11            6                   5
# 99   laporan           2            4            5                   4
#
#     Assignor_Rating_Q2  Nilai_Quartal_1  Nilai_Quartal_2    Predikat  \
# 0                    2        95.000000        87.909091   91.454545
# 1                    5        98.615385       102.125000  100.370192
# 2                    4        92.000000        70.000000   81.000000
# 3                    1        92.000000        88.000000   90.000000
# 4                    1        64.000000        84.000000   74.000000
# ..                 ...              ...              ...         ...
# 95                   1        83.714286        40.000000   61.857143
# 96                   1        92.000000        68.000000   80.000000
# 97                   1        48.000000        84.000000   66.000000
# 98                   4       104.000000        91.428571   97.714286
# 99                   2        56.000000        53.428571   54.714286
#
#        Tanggal Kategori_Predikat
# 0   2024-08-08         Memuaskan
# 1   2024-08-08  Sangat Memuaskan
# 2   2024-08-08              Baik
# 3   2024-08-08         Memuaskan
# 4   2024-08-08              Baik
# ..         ...               ...
# 95  2024-08-08             Cukup
# 96  2024-08-08              Baik
# 97  2024-08-08             Cukup
# 98  2024-08-08         Memuaskan
# 99  2024-08-08             Cukup
#
# [100 rows x 20 columns]

# %%
data = data.dropna()
data
# Out:
#             NIP             Nama        Jabatan  \
# 0   466-60-3518   Bradley Galvan  Staff Operasi
# 1   167-52-0691    Sharon Harris  Staff Operasi
# 2   377-11-9746       David Cook  Staff Operasi
# 3   818-12-3550      Aaron Smith  Staff Operasi
# 4   342-94-2910  Leslie Mckinney  Staff Operasi
# ..          ...              ...            ...
# 95  232-54-4400  Heather Roberts  Staff Operasi
# 96  692-51-4169       Jon Dawson  Staff Operasi
# 97  206-64-5705     Teresa Lynch  Staff Operasi
# 98  574-87-7256     Adriana Hart  Staff Operasi
# 99  299-02-8126   Daniel Johnson  Staff Operasi
#
#                                           Objective_1  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2   Meningkatkan efektifitas sumber daya penunjang...
# 3   Meningkatkan efektifitas sumber daya penunjang...
# 4   Meningkatkan efektifitas sumber daya penunjang...
# ..                                                ...
# 95  Menurunkan tingkat iregularitas sesuai target ...
# 96  Menurunkan tingkat iregularitas sesuai target ...
# 97  Menurunkan tingkat iregularitas sesuai target ...
# 98  Menurunkan tingkat iregularitas sesuai target ...
# 99  Meningkatkan efektifitas sumber daya penunjang...
#
#                                          Key_Result_1  \
# 0   Tersedianya laporan pola operasi tersier setia...
# 1   Tercapainya kinerja SWP Pos Same Day Wilker (K...
# 2   Tercapainya optimalisasi kbm tersier setiap bulan
# 3   Tersedianya laporan evaluasi implementasi oran...
# 4   Tercapainya optimalisasi kbm tersier setiap bulan
# ..                                                ...
# 95  Tercapainya penurunan jumlah kiriman gagal xra...
# 96  Tercapainya keberangkatan moda angkutan sesuai...
# 97  Tersedianya laporan evaluasi kiriman iregulari...
# 98  Tersedianya laporan evaluasi kiriman iregulari...
# 99  Tersedianya monitoring kebutuhan dan penataan ...
#
#                                           Objective_2  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2             Mendorong efisiensi cost bidang operasi
# 3             Mendorong efisiensi cost bidang operasi
# 4             Mendorong efisiensi cost bidang operasi
# ..                                                ...
# 95            Mendorong efisiensi cost bidang operasi
# 96  Meningkatkan efektifitas sumber daya penunjang...
# 97            Mendorong efisiensi cost bidang operasi
# 98            Mendorong efisiensi cost bidang operasi
# 99            Mendorong efisiensi cost bidang operasi
#
#                                          Key_Result_2  Target_Q1  Target_Q2  \
# 0   Tercapainya optimalisasi pola operasi tersier ...         60         88
# 1   Tercapainya kinerja SWP Pos Reguler Wilker (KC...         78         64
# 2   Tersedianya monitoring kebutuhan dan penataan ...          1          2
# 3   Tercapainya optimalisasi kbm tersier setiap bulan          5          6
# 4   Tersedianya laporan evaluasi implementasi oran...         15         15
# ..                                                ...        ...        ...
# 95  Tercapainya keberangkatan moda angkutan sesuai...         14          5
# 96  Tersedianya laporan evaluasi kiriman iregulari...         10          9
# 97  Tersedianya laporan keberangkatan moda angkuta...         15         15
# 98  Tercapainya penurunan jumlah kiriman gagal xra...         11          7
# 99  Tersedianya laporan evaluasi implementasi oran...         15         14
#
#         Unit  Complexity  Progress_Q1  Progress_Q2  Assignor_Rating_Q1  \
# 0    percent           1           59           82                   3
# 1    percent           1           71           62                   5
# 2    laporan           4            1            1                   2
# 3   kegiatan           1            4            6                   5
# 4   kegiatan           5            7           14                   3
# ..       ...         ...          ...          ...                 ...
# 95  kegiatan           3           13            1                   1
# 96   laporan           1           10            6                   2
# 97  kegiatan           2            2           14                   4
# 98  kegiatan           2           11            6                   5
# 99   laporan           2            4            5                   4
#
#     Assignor_Rating_Q2  Nilai_Quartal_1  Nilai_Quartal_2    Predikat  \
# 0                    2        95.000000        87.909091   91.454545
# 1                    5        98.615385       102.125000  100.370192
# 2                    4        92.000000        70.000000   81.000000
# 3                    1        92.000000        88.000000   90.000000
# 4                    1        64.000000        84.000000   74.000000
# ..                 ...              ...              ...         ...
# 95                   1        83.714286        40.000000   61.857143
# 96                   1        92.000000        68.000000   80.000000
# 97                   1        48.000000        84.000000   66.000000
# 98                   4       104.000000        91.428571   97.714286
# 99                   2        56.000000        53.428571   54.714286
#
#        Tanggal Kategori_Predikat
# 0   2024-08-08         Memuaskan
# 1   2024-08-08  Sangat Memuaskan
# 2   2024-08-08              Baik
# 3   2024-08-08         Memuaskan
# 4   2024-08-08              Baik
# ..         ...               ...
# 95  2024-08-08             Cukup
# 96  2024-08-08              Baik
# 97  2024-08-08             Cukup
# 98  2024-08-08         Memuaskan
# 99  2024-08-08             Cukup
#
# [100 rows x 20 columns]

# %%
# Mengecek data missing value
data.isnull().sum()
# Out:
# NIP                   0
# Nama                  0
# Jabatan               0
# Objective_1           0
# Key_Result_1          0
# Objective_2           0
# Key_Result_2          0
# Target_Q1             0
# Target_Q2             0
# Unit                  0
# Complexity            0
# Progress_Q1           0
# Progress_Q2           0
# Assignor_Rating_Q1    0
# Assignor_Rating_Q2    0
# Nilai_Quartal_1       0
# Nilai_Quartal_2       0
# Predikat              0
# Tanggal               0
# Kategori_Predikat     0
# dtype: int64

# %%
# Title info type data
print('Tipe Data Sebelum:\n')
data.info()
# Out:
# Tipe Data Sebelum:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NIP                 100 non-null    object
#  1   Nama                100 non-null    object
#  2   Jabatan             100 non-null    object
#  3   Objective_1         100 non-null    object
#  4   Key_Result_1        100 non-null    object
#  5   Objective_2         100 non-null    object
#  6   Key_Result_2        100 non-null    object
#  7   Target_Q1           100 non-null    int64
#  8   Target_Q2           100 non-null    int64
#  9   Unit                100 non-null    object
#  10  Complexity          100 non-null    int64
#  11  Progress_Q1         100 non-null    int64
#  12  Progress_Q2         100 non-null    int64
#  13  Assignor_Rating_Q1  100 non-null    int64
#  14  Assignor_Rating_Q2  100 non-null    int64
#  15  Nilai_Quartal_1     100 non-null    float64
#  16  Nilai_Quartal_2     100 non-null    float64
#  17  Predikat            100 non-null    float64
#  18  Tanggal             100 non-null    object
#  19  Kategori_Predikat   100 non-null    object
# dtypes: float64(3), int64(7), object(10)
# memory usage: 15.8+ KB

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['NIP', 'Nama', 'Jabatan', 'Objective_1', 'Key_Result_1', 'Objective_2',
#        'Key_Result_2', 'Unit', 'Tanggal', 'Kategori_Predikat'],
#       dtype='object')
# Numerical Variables:
# ['Target_Q1', 'Target_Q2', 'Complexity', 'Progress_Q1', 'Progress_Q2', 'Assignor_Rating_Q1', 'Assignor_Rating_Q2', 'Nilai_Quartal_1', 'Nilai_Quartal_2', 'Predikat']

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NIP                 100 non-null    object
#  1   Nama                100 non-null    object
#  2   Jabatan             100 non-null    object
#  3   Objective_1         100 non-null    object
#  4   Key_Result_1        100 non-null    object
#  5   Objective_2         100 non-null    object
#  6   Key_Result_2        100 non-null    object
#  7   Target_Q1           100 non-null    int64
#  8   Target_Q2           100 non-null    int64
#  9   Unit                100 non-null    object
#  10  Complexity          100 non-null    int64
#  11  Progress_Q1         100 non-null    int64
#  12  Progress_Q2         100 non-null    int64
#  13  Assignor_Rating_Q1  100 non-null    int64
#  14  Assignor_Rating_Q2  100 non-null    int64
#  15  Nilai_Quartal_1     100 non-null    float64
#  16  Nilai_Quartal_2     100 non-null    float64
#  17  Predikat            100 non-null    float64
#  18  Tanggal             100 non-null    object
#  19  Kategori_Predikat   100 non-null    object
# dtypes: float64(3), int64(7), object(10)
# memory usage: 15.8+ KB
# None
#         Target_Q1   Target_Q2  Complexity  Progress_Q1  Progress_Q2  \
# count  100.000000  100.000000  100.000000   100.000000     100.0000
# mean    25.940000   26.300000    2.770000    21.070000      20.5000
# std     28.440553   29.395423    1.441485    26.064898      25.4211
# min      1.000000    1.000000    1.000000     1.000000       1.0000
# 25%      6.000000    6.000000    1.000000     2.000000       3.0000
# 50%     12.000000   12.000000    3.000000     7.000000       6.0000
# 75%     56.000000   52.250000    4.000000    52.000000      50.0000
# max     94.000000   99.000000    5.000000    86.000000      92.0000
#
#        Assignor_Rating_Q1  Assignor_Rating_Q2  Nilai_Quartal_1  \
# count          100.000000          100.000000       100.000000
# mean             3.000000            3.090000        77.243891
# std              1.530828            1.386042        17.826711
# min              1.000000            1.000000        37.000000
# 25%              1.750000            2.000000        61.928571
# 50%              3.000000            3.000000        83.501832
# 75%              4.000000            4.000000        92.000000
# max              5.000000            5.000000       104.000000
#
#        Nilai_Quartal_2    Predikat
# count       100.000000  100.000000
# mean         77.447623   77.345757
# std          16.922478   13.669688
# min          38.000000   37.500000
# 25%          65.660714   66.000000
# 50%          80.000000   78.620802
# 75%          90.357143   89.511364
# max         104.000000  104.000000

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
X = data.drop(['Kategori_Predikat', 'Predikat', 'NIP', 'Nama', 'Jabatan', 'Unit', 'Tanggal'], axis=1)
y = data['Kategori_Predikat']

# %%
X = data[['Objective_1', 'Key_Result_1', 'Objective_2', 'Key_Result_2', 'Target_Q1', 'Target_Q2', 'Complexity', 'Progress_Q1', 'Progress_Q2', 'Assignor_Rating_Q1', 'Assignor_Rating_Q2', 'Nilai_Quartal_1', 'Nilai_Quartal_2', 'Predikat', 'Kategori_Predikat']]
X
# Out:
#                                           Objective_1  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2   Meningkatkan efektifitas sumber daya penunjang...
# 3   Meningkatkan efektifitas sumber daya penunjang...
# 4   Meningkatkan efektifitas sumber daya penunjang...
# ..                                                ...
# 95  Menurunkan tingkat iregularitas sesuai target ...
# 96  Menurunkan tingkat iregularitas sesuai target ...
# 97  Menurunkan tingkat iregularitas sesuai target ...
# 98  Menurunkan tingkat iregularitas sesuai target ...
# 99  Meningkatkan efektifitas sumber daya penunjang...
#
#                                          Key_Result_1  \
# 0   Tersedianya laporan pola operasi tersier setia...
# 1   Tercapainya kinerja SWP Pos Same Day Wilker (K...
# 2   Tercapainya optimalisasi kbm tersier setiap bulan
# 3   Tersedianya laporan evaluasi implementasi oran...
# 4   Tercapainya optimalisasi kbm tersier setiap bulan
# ..                                                ...
# 95  Tercapainya penurunan jumlah kiriman gagal xra...
# 96  Tercapainya keberangkatan moda angkutan sesuai...
# 97  Tersedianya laporan evaluasi kiriman iregulari...
# 98  Tersedianya laporan evaluasi kiriman iregulari...
# 99  Tersedianya monitoring kebutuhan dan penataan ...
#
#                                           Objective_2  \
# 0             Mendorong efisiensi cost bidang operasi
# 1             Mendorong efisiensi cost bidang operasi
# 2             Mendorong efisiensi cost bidang operasi
# 3             Mendorong efisiensi cost bidang operasi
# 4             Mendorong efisiensi cost bidang operasi
# ..                                                ...
# 95            Mendorong efisiensi cost bidang operasi
# 96  Meningkatkan efektifitas sumber daya penunjang...
# 97            Mendorong efisiensi cost bidang operasi
# 98            Mendorong efisiensi cost bidang operasi
# 99            Mendorong efisiensi cost bidang operasi
#
#                                          Key_Result_2  Target_Q1  Target_Q2  \
# 0   Tercapainya optimalisasi pola operasi tersier ...         60         88
# 1   Tercapainya kinerja SWP Pos Reguler Wilker (KC...         78         64
# 2   Tersedianya monitoring kebutuhan dan penataan ...          1          2
# 3   Tercapainya optimalisasi kbm tersier setiap bulan          5          6
# 4   Tersedianya laporan evaluasi implementasi oran...         15         15
# ..                                                ...        ...        ...
# 95  Tercapainya keberangkatan moda angkutan sesuai...         14          5
# 96  Tersedianya laporan evaluasi kiriman iregulari...         10          9
# 97  Tersedianya laporan keberangkatan moda angkuta...         15         15
# 98  Tercapainya penurunan jumlah kiriman gagal xra...         11          7
# 99  Tersedianya laporan evaluasi implementasi oran...         15         14
#
#     Complexity  Progress_Q1  Progress_Q2  Assignor_Rating_Q1  \
# 0            1           59           82                   3
# 1            1           71           62                   5
# 2            4            1            1                   2
# 3            1            4            6                   5
# 4            5            7           14                   3
# ..         ...          ...          ...                 ...
# 95           3           13            1                   1
# 96           1           10            6                   2
# 97           2            2           14                   4
# 98           2           11            6                   5
# 99           2            4            5                   4
#
#     Assignor_Rating_Q2  Nilai_Quartal_1  Nilai_Quartal_2    Predikat  \
# 0                    2        95.000000        87.909091   91.454545
# 1                    5        98.615385       102.125000  100.370192
# 2                    4        92.000000        70.000000   81.000000
# 3                    1        92.000000        88.000000   90.000000
# 4                    1        64.000000        84.000000   74.000000
# ..                 ...              ...              ...         ...
# 95                   1        83.714286        40.000000   61.857143
# 96                   1        92.000000        68.000000   80.000000
# 97                   1        48.000000        84.000000   66.000000
# 98                   4       104.000000        91.428571   97.714286
# 99                   2        56.000000        53.428571   54.714286
#
#    Kategori_Predikat
# 0          Memuaskan
# 1   Sangat Memuaskan
# 2               Baik
# 3          Memuaskan
# 4               Baik
# ..               ...
# 95             Cukup
# 96              Baik
# 97             Cukup
# 98         Memuaskan
# 99             Cukup
#
# [100 rows x 15 columns]

# %% [markdown]
# ## Normaslisasi

# %%
from sklearn.preprocessing import StandardScaler

def normalize_data(data, columns_to_normalize):
    scaler = StandardScaler()
    data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])
    return data

# Kolom-kolom numerik yang akan dinormalisasi
columns_numeric = ['Target_Q1', 'Target_Q2', 'Complexity', 'Progress_Q1', 'Progress_Q2', 'Assignor_Rating_Q1', 'Assignor_Rating_Q2', 'Nilai_Quartal_1', 'Nilai_Quartal_2', 'Predikat']

# Memanggil fungsi normalize_data hanya untuk kolom numerik
data_normalized = normalize_data(data, columns_numeric)

# Menampilkan DataFrame yang sudah dinormalisasi
print("Mean values after normalization:")
print(data_normalized[columns_numeric].mean())

print("\nStandard deviation values after normalization:")
print(data_normalized[columns_numeric].std())
# Out:
# Mean values after normalization:
# Target_Q1             7.216450e-18
# Target_Q2            -2.609024e-17
# Complexity            2.442491e-17
# Progress_Q1          -2.886580e-17
# Progress_Q2           1.332268e-17
# Assignor_Rating_Q1   -4.440892e-18
# Assignor_Rating_Q2    4.551914e-17
# Nilai_Quartal_1      -6.994405e-16
# Nilai_Quartal_2      -6.972201e-16
# Predikat              1.241229e-15
# dtype: float64
#
# Standard deviation values after normalization:
# Target_Q1             1.005038
# Target_Q2             1.005038
# Complexity            1.005038
# Progress_Q1           1.005038
# Progress_Q2           1.005038
# Assignor_Rating_Q1    1.005038
# Assignor_Rating_Q2    1.005038
# Nilai_Quartal_1       1.005038
# Nilai_Quartal_2       1.005038
# Predikat              1.005038
# dtype: float64

# %% [markdown]
# ## Encoded Data

# %%
# Misalkan X adalah DataFrame awal
# ... (kode untuk mendefinisikan DataFrame X)

# Copy DataFrame agar tidak merubah DataFrame asli
data_encoded = X.copy()

# Inisialisasi LabelEncoder
label_encoder = LabelEncoder()

# Lakukan label encoding pada kolom
data_encoded['Objective_1'] = label_encoder.fit_transform(X['Objective_1'])
data_encoded['Key_Result_1'] = label_encoder.fit_transform(X['Key_Result_1'])

# Lakukan label encoding pada kolom
data_encoded['Objective_2'] = label_encoder.fit_transform(X['Objective_2'])
data_encoded['Key_Result_2'] = label_encoder.fit_transform(X['Key_Result_2'])

# Tampilkan DataFrame hasil
print(data_encoded)
# Out:
#     Objective_1  Key_Result_1  Objective_2  Key_Result_2  Target_Q1  \
# 0             0            13            0             7         60
# 1             0             5            0             4         78
# 2             1             6            0            14          1
# 3             1            10            0             6          5
# 4             1             6            0            10         15
# ..          ...           ...          ...           ...        ...
# 95            2             9            0             2         14
# 96            2             2            1            11         10
# 97            2            11            0            12         15
# 98            2            11            0             9         11
# 99            1            14            0            10         15
#
#     Target_Q2  Complexity  Progress_Q1  Progress_Q2  Assignor_Rating_Q1  \
# 0          88           1           59           82                   3
# 1          64           1           71           62                   5
# 2           2           4            1            1                   2
# 3           6           1            4            6                   5
# 4          15           5            7           14                   3
# ..        ...         ...          ...          ...                 ...
# 95          5           3           13            1                   1
# 96          9           1           10            6                   2
# 97         15           2            2           14                   4
# 98          7           2           11            6                   5
# 99         14           2            4            5                   4
#
#     Assignor_Rating_Q2  Nilai_Quartal_1  Nilai_Quartal_2    Predikat  \
# 0                    2        95.000000        87.909091   91.454545
# 1                    5        98.615385       102.125000  100.370192
# 2                    4        92.000000        70.000000   81.000000
# 3                    1        92.000000        88.000000   90.000000
# 4                    1        64.000000        84.000000   74.000000
# ..                 ...              ...              ...         ...
# 95                   1        83.714286        40.000000   61.857143
# 96                   1        92.000000        68.000000   80.000000
# 97                   1        48.000000        84.000000   66.000000
# 98                   4       104.000000        91.428571   97.714286
# 99                   2        56.000000        53.428571   54.714286
#
#    Kategori_Predikat
# 0          Memuaskan
# 1   Sangat Memuaskan
# 2               Baik
# 3          Memuaskan
# 4               Baik
# ..               ...
# 95             Cukup
# 96              Baik
# 97             Cukup
# 98         Memuaskan
# 99             Cukup
#
# [100 rows x 15 columns]

# %% [markdown]
# ## Split Data

# %%
# Pilih fitur dan target
features = ['Objective_1', 'Key_Result_1', 'Key_Result_2', 'Objective_2', 'Target_Q1', 'Target_Q2', 'Complexity', 'Progress_Q1', 'Progress_Q2', 'Assignor_Rating_Q1', 'Assignor_Rating_Q2', 'Nilai_Quartal_1', 'Nilai_Quartal_2', 'Predikat']
X_features = data_encoded[features]
y = data_encoded['Kategori_Predikat']

# Split data menjadi train dan test set
X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.2, random_state=42)

# Tampilkan ukuran dari train dan test set
print("Train set size:", X_train.shape[0])
print("Test set size:", X_test.shape[0])
# Out:
# Train set size: 80
# Test set size: 20

# %% [markdown]
# ## Model Training

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# [[7 0 0 0]
#  [0 6 0 0]
#  [0 0 6 1]
#  [0 0 0 0]]
#                   precision    recall  f1-score   support
#
#             Baik       1.00      1.00      1.00         7
#            Cukup       1.00      1.00      1.00         6
#        Memuaskan       1.00      0.86      0.92         7
# Sangat Memuaskan       0.00      0.00      0.00         0
#
#         accuracy                           0.95        20
#        macro avg       0.75      0.71      0.73        20
#     weighted avg       1.00      0.95      0.97        20
#
# Accuracy: 0.95
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Verifikasi path Graphviz
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'

# Visualisasikan pohon keputusan
dot_data = export_graphviz(clf, out_file=None, 
                           feature_names=X_test.columns,  
                           class_names=clf.classes_,  
                           filled=True, rounded=True,  
                           special_characters=True)

graph = graphviz.Source(dot_data)
graph.render("pohonkeputusan")  # Menyimpan hasil ke file
graph

# %% [markdown]
# ## Model Evaluation

# %%
# Menghitung metrik evaluasi
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Menampilkan hasil evaluasi
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 1.0
# Recall: 0.95
# F1 Score: 0.973076923076923
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
test_accuracy = clf.score(X_test, y_test)

print(f"Accuracy on test set: {test_accuracy:.2f}")
# Out:
# Accuracy on test set: 0.95

# %%
# Menampilkan classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#             Baik       1.00      1.00      1.00         7
#            Cukup       1.00      1.00      1.00         6
#        Memuaskan       1.00      0.86      0.92         7
# Sangat Memuaskan       0.00      0.00      0.00         0
#
#         accuracy                           0.95        20
#        macro avg       0.75      0.71      0.73        20
#     weighted avg       1.00      0.95      0.97        20
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=clf.classes_, yticklabels=clf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
with open('decision_tree_model.pkl', 'wb') as file:
    pickle.dump(clf, file)
print("Model saved to 'decision_tree_model.pkl'")
# Out:
# Model saved to 'decision_tree_model.pkl'
